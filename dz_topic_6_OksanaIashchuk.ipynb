# %% [markdown]
# <h1 style="text-align: center;">6. «Класифікація зображень»
# </h1>
# <h2 style="text-align: center;">Homework assignment for the «Класифікація зображень» module.</h2>

# %% [markdown]
# 🎢 Домашнє завдання до модуля «Класифікація зображень»
#
# Привіт 😉
# У цьому домашньому завданні ви матимете можливість застосувати свої знання та навички для вирішення реальної задачі класифікації зображень. Ви будете працювати з набором даних Intel Image Classification, який містить близько 25 000 зображень природних сцен з усього світу, розподілених на 6 категорій.
# Ваше завдання полягає в розробці та навчанні моделі глибокого навчання для класифікації зображень з набору даних Intel Image Classification. Кожне зображення має розмір 150x150 пікселів і належить до однієї з 6 категорій природних сцен.
# Вам потрібно:
# 1. Завантажити та підготувати набір даних для обробки.
# 2. Розробити архітектуру згорткової нейронної мережі (CNN) для класифікації зображень.
# 3. Навчити модель на тренувальному наборі даних.
# 4. Оцінити ефективність моделі на валідаційному та тестовому наборах даних.
# 5. Проаналізувати результати та запропонувати можливі покращення моделі.
#
# Ваша кінцева мета — створити модель, яка зможе точно класифікувати нові зображення природних сцен за відповідними категоріями.
#
#
# Покрокова інструкція виконання
# 1. Здійсніть імпорт необхідних бібліотек.
# 2. Підготовка даних:
# Завантажте набір даних Intel Image Classification з платформи Kaggle.
# Розділіть дані на тренувальний, валідаційний та тестовий набори. Дані вже розділені на навчальні та тестові. Вам слід відділити частину навчальних даних для отримання валідаційного набору даних.
# Використайте torchvision.datasets і torch.utils.data.DataLoader для завантаження та підготовки даних.
# 2. Попередня обробка зображень:
# Застосуйте необхідні перетворення (наприклад, зміна розміру, нормалізація) за допомогою torchvision.transforms.
# 3. Створення моделі: Варіант A: Проста згорткова нейронна мережа
# Створіть власну архітектуру CNN за допомогою torch.nn.
# Визначте шари згортки (Conv2d), активації (ReLU), пулінгу (MaxPool2d) та повнозв'язні шари (Linear).
# 4. Варіант B: Transfer Learning
# Імпортуйте попередньо навчену модель (наприклад, ResNet18) з torchvision.models.
# Модифікуйте останній шар відповідно до кількості класів у вашому завданні.
# 5. Визначення функції втрат та оптимізатора:
# Виберіть відповідну функцію втрат (наприклад, CrossEntropyLoss). Обґрунтуйте вибір функції втрат.
# Виберіть оптимізатор (наприклад, Adam або SGD).
# 6. Навчання моделі:
# Напишіть цикл навчання з використанням PyTorch.
# Обчислюйте втрати, виконуйте зворотне поширення та оновлюйте ваги.
# Зберігайте модель з найкращими показниками на валідаційному наборі.
# 7. Оцінка моделі:
# Оцініть продуктивність моделі на тестовому наборі даних.
# Обчисліть метрики, наприклад F1-score тощо. Обґрунтуйте вибір метрики.
# 8. Аналіз результатів:
# Візуалізуйте результати (наприклад, матрицю помилок, криві навчання).
# Проаналізуйте помилки класифікації.
# 9. Покращення моделі (опціонально):
# Спробуйте різні архітектури або гіперпараметри.
# Експериментуйте з методами аугментації даних.
# Додаткові поради:
# Використовуйте GPU, якщо доступно, для прискорення навчання.
# При використанні transfer learning, спробуйте «заморозити» деякі шари попередньо навченої моделі.
#
# Орієнтовний очікуваний результат
# Орієнтовні результати метрик для цього завдання можуть варіюватися залежно від конкретної реалізації.
# 1. Проста нейронна мережа:
# Використовуючи просту згорткову нейронну мережу (CNN), розроблену з нуля, студент може очікувати наступні результати:
# точність (аccuracy): 75-85%,
# F1-score: 0.73-0.83.
# Ці результати залежатимуть від архітектури мережі, кількості епох навчання, розміру батчу та швидкості навчання.
# 2. Переніс навчання (Transfer Learning):
# Використовуючи попередньо навчену модель (наприклад, ResNet18 або VGG16) з доналаштуванням для даного завдання, студент може досягти значно кращих результатів:
# точність (аccuracy): 90-97%,
# F1-score: 0.89-0.96.
# Ці покращені результати пояснюються тим, що попередньо навчені моделі вже мають сформовані потужні ознаки для розпізнавання зображень, які можна ефективно адаптувати до конкретного набору даних.
# ☝🏻 Важливо зазначити:
# 1. Ці оцінки є приблизними і можуть відрізнятися залежно від конкретної реалізації та гіперпараметрів.
# 2. Переніс навчання зазвичай дає кращі результати, особливо коли розмір навчального набору даних обмежений.
# 3. Проста модель може вимагати більше часу для навчання і експериментів з гіперпараметрами для досягнення хороших результатів.
# 4. Навіть з простою моделлю, застосування методів аугментації даних може покращити результати.
# 5. Для перенесення навчання вибір відповідної попередньо навченої моделі та стратегії доналаштування (fine-tuning) може суттєво вплинути на кінцеві результати.
#
# Ці орієнтовні результати можуть допомогти вам оцінити ефективність своїх моделей та зрозуміти, чи ви рухаєтесь у правильному напрямку з їхньою реалізацією.
#
# Навіть якщо ви застосували просту нейронну мережу, ви все ще можете отримати високу оцінку, якщо:
# 1. Детально проаналізуєте отримані результати:
# Поясніть, чому модель могла не досягти очікуваних показників.
# Обговоріть можливі обмеження даних або обраного підходу.
# 2. Критично оціните архітектуру вашої моделі:
# Опишіть, чому ви обрали саме таку структуру нейронної мережі.
# Розгляньте потенційні недоліки вашої архітектури.
# 3. Запропонуєте шляхи покращення:
# Надайте конкретні ідеї щодо оптимізації моделі.
# Обговоріть альтернативні підходи, які могли б дати кращі результати.
# ☝🏻 Пам'ятайте, що в реальному світі не завжди вдається досягти ідеальних результатів з першої спроби. Вміння аналізувати, робити висновки та пропонувати покращення є надзвичайно цінними навичками в галузі машинного навчання.
# Ваша здатність критично мислити, аналізувати результати та пропонувати обґрунтовані покращення є ключовими факторами для високої оцінки цього завдання.
#
# Критерії прийняття та оцінювання ДЗ
# ☝🏻 Критерії прийняття домашнього завдання є обов’язковою умовою оцінювання домашнього завдання ментором. Якщо якийсь з критеріїв не виконано, ДЗ відправляється ментором на доопрацювання без оцінювання.
# Якщо вам «тільки уточнити»😉 або ви «застопорилися» на якомусь з етапів виконання — звертайтеся до ментора у Slack).
# 1. Код виконується.
# 2. Підготовка даних (15 балів):
# завантаження та підготовка даних (5 балів),
# розподіл на тренувальний та валідаційний набори (5 балів),
# попередня обробка зображень (5 балів).
# 3. Створення моделі (15 балів):
# Реалізація простої CNN або застосування transfer learning (15 балів).
# 4. Налаштування та навчання (20 балів):
# вибір функції втрат та оптимізатора (5 балів),
# реалізація циклу навчання з відстеженням прогресу (10 балів),
# обґрунтований вибір гіперпараметрів (5 балів).
# 5. Оцінка моделі (20 балів):
# обчислення метрик ефективності (10 балів),
# інтерпретація отриманих метрик (10 балів).
# 6. Аналіз результатів (30 балів):
# візуалізація фактичних та прогнозованих значень на навчальному, валідаційному та тестовому наборах даних (15 балів),
# змістовні висновки та пропозиції щодо можливих покращень (15 балів).
# 7. Додатково:
# спроби оптимізації моделі (експерименти з архітектурою, гіперпараметрами) (+10 балів)

# %% [markdown]
# ## 1. **Import the required libraries.**

# %%
# Reproducibility + essentials
import os, random, time, copy
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

def set_seed(seed=42):
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# ## 2. **Data preparation:**

# %% [markdown]
# Завантажте набір даних Intel Image Classification з платформи Kaggle.
#
# Розділіть дані на тренувальний, валідаційний та тестовий набори. Дані вже розділені на навчальні та тестові. Вам слід відділити частину навчальних даних для отримання валідаційного набору даних.
#
# Використайте torchvision.datasets і torch.utils.data.DataLoader для завантаження та підготовки даних.
#
# Попередня обробка зображень: Застосуйте необхідні перетворення (наприклад, зміна розміру, нормалізація) за допомогою torchvision.transforms.
#
# ---
# Опис:
# Дані лежать у папці IntelImageClassificationDataset.
#
# Усередині:
#
# seg_train/seg_train — тренувальні зображення,
#
# seg_test/seg_test — тестові зображення.
#
# Ділимо train на train (80%) і val (20%).
#
# Використовуємо базові трансформації: Resize → ToTensor → Normalize.

# %%
# Трансформації (Resize -> ToTensor -> Normalize)
train_tfms = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])
test_tfms = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
])

# Шляхи до даних
train_dir = "./IntelImageClassificationDataset/seg_train/seg_train"
test_dir  = "./IntelImageClassificationDataset/seg_test/seg_test"

# Завантаження train і test
full_train = datasets.ImageFolder(root=train_dir, transform=train_tfms)
test_ds    = datasets.ImageFolder(root=test_dir,  transform=test_tfms)

# Розділення train -> train + val
val_size   = int(0.2 * len(full_train))
train_size = len(full_train) - val_size
train_ds, val_ds = random_split(full_train, [train_size, val_size])

# DataLoader
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl   = DataLoader(val_ds, batch_size=32, shuffle=False)
test_dl  = DataLoader(test_ds, batch_size=32, shuffle=False)

# Перевірка
print("Train samples:", len(train_ds))
print("Val samples:", len(val_ds))
print("Test samples:", len(test_ds))
print("Classes:", full_train.classes)
# Out:
# Train samples: 11228
# Val samples: 2806
# Test samples: 3000
# Classes: ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %% [markdown]
# ## 3. **Створення моделі: Варіант A: Проста згорткова нейронна мережа.**
#
# Створіть власну архітектуру CNN за допомогою torch.nn.
#
# Визначте шари згортки (Conv2d), активації (ReLU), пулінгу (MaxPool2d) та повнозв'язні шари (Linear).
#
# Опис:
#
# Завдання — класифікація зображень на 6 класів (категорій природних сцен).
#
# Будуємо власну просту згорткову нейронну мережу (CNN) «з нуля».
#
# Архітектура:
#
# Кілька блоків Conv2d → ReLU → MaxPool2d для виділення ознак.
#
# Наприкінці — Linear шари для класифікації.
#
# Вихідний шар має розмір = кількість класів (len(full_train.classes)).

# %%
class SimpleCNN(nn.Module):
    def __init__(self, num_classes):
        super(SimpleCNN, self).__init__()
        
        self.conv_layers = nn.Sequential(
            # Block 1
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # 3 канали -> 32 фільтри (стандарт для маленьких CNN). на реальних проектах доцільно збільшити
            nn.ReLU(),
            nn.MaxPool2d(2),  # зменшення розміру вдвічі
            
            # Block 2
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            
            # Block 3
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
        self.fc_layers = nn.Sequential(
            nn.Flatten() # це стає вектором довжини 128 × 18 × 18 = 41 472 . розмір залежить від вхідного зображення (150x150 -> 18x18 після 3 пулінгів)
            nn.Linear(128 * 18 * 18, 256),  # спочатку стискаємо до 256 нейронів. 
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes) # Вихідний шар → 6 класів (бо у нас 6 категорій: buildings, forest, glacier, mountain, sea, street)
        )
        
    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x

# Ініціалізація моделі
num_classes = len(full_train.classes)
model = SimpleCNN(num_classes).to(device)

print(model)
# Out:
# SimpleCNN(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=41472, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.3, inplace=False)
#     (4): Linear(in_features=256, out_features=6, bias=True)
#   )
# )

# %% [markdown]
# ## 4. **Варіант B: Transfer Learning**
#
# Імпортуйте попередньо навчену модель (наприклад, ResNet18) з torchvision.models.
#
# Модифікуйте останній шар відповідно до кількості класів у вашому завданні.
#
# Опис:
#
# Беремо ResNet18 з torchvision.models з попередньо навченими вагами.
#
# заморожуємо backbone, щоб вчитись лише останнім шаром.
#
# Замінюємо фінальний fc на Linear(..., num_classes).

# %%
# num_classes = len(full_train.classes)  # 6 для Intel dataset

def build_resnet18(num_classes: int, freeze_backbone: bool = True):
    # завантажуємо модель з предтреном
    model = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
    
    # заморожуємо всі параметри бекбону
    if freeze_backbone:
        for p in model.parameters():
            p.requires_grad = False
    
    # замінюємо останній повнозв'язний шар під наші класи
    in_features = model.fc.in_features
    model.fc = nn.Linear(in_features, num_classes)
    return model

# створюємо модель і переносимо на девайс
model = build_resnet18(num_classes=num_classes, freeze_backbone=True).to(device) # freeze_backbone=True — швидкий старт (вчимо лише новий fc), зазвичай уже дає високу точність.


learnable_params = [p for p in model.parameters() if p.requires_grad]
print("Model ready (ResNet18 TL). Trainable params:",
      sum(p.numel() for p in learnable_params))
# Out:
# Model ready (ResNet18 TL). Trainable params: 3078

# %% [markdown]
# ## 5. **Визначення функції втрат та оптимізатора:**
#
# Виберіть відповідну функцію втрат (наприклад, CrossEntropyLoss). Обґрунтуйте вибір функції втрат.
#
# Виберіть оптимізатор (наприклад, Adam або SGD).
#
# Опис:
#
# Оскільки це багатокласова класифікація, стандартним вибором є CrossEntropyLoss.
# Вона поєднує LogSoftmax + NLLLoss, тому не потрібно явно додавати Softmax у модель.
#
# Для оптимізації можна використати Adam, бо він добре працює й швидше сходиться, ніж звичайний SGD.
#
# Гіперпараметри:
#
# lr = 1e-3 — класичне стартове значення для Adam,
#
# weight_decay = 1e-4 — додає легку L2-регуляризацію, щоб уникати перенавчання.

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

print("Loss function:", criterion)
print("Optimizer:", optimizer)
# Out:
# Loss function: CrossEntropyLoss()
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0.0001
# )

# %% [markdown]
# ## 6. **Навчання моделі:**
#
# Напишіть цикл навчання з використанням PyTorch.
#
# Обчислюйте втрати, виконуйте зворотне поширення та оновлюйте ваги.
#
# Зберігайте модель з найкращими показниками на валідаційному наборі.
#
# Опис:
#
# Проходимо епохами: для кожної — тренування на train_dl, потім оцінка на val_dl.
#
# Рахуємо loss та accuracy для train/val.
#
# Зберігаємо найкращі ваги за валід. accuracy.
#
# Ведемо історію для кривих навчання.

# %%
# Training loop with validation + save best by val accuracy

EPOCHS = 25  

history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
best_acc = 0.0
best_state = None

for epoch in range(1, EPOCHS + 1):
    # ---- TRAIN ----
    model.train()
    train_loss_sum, train_correct, train_total = 0.0, 0, 0

    for xb, yb in train_dl:
        xb, yb = xb.to(device), yb.to(device)

        logits = model(xb)
        loss = criterion(logits, yb)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss_sum += loss.item() * xb.size(0)
        preds = logits.argmax(1)
        train_correct += (preds == yb).sum().item()
        train_total += xb.size(0)

    train_loss = train_loss_sum / train_total
    train_acc  = train_correct / train_total

    # ---- VALIDATION ----
    model.eval()
    val_loss_sum, val_correct, val_total = 0.0, 0, 0

    with torch.no_grad():
        for xb, yb in val_dl:
            xb, yb = xb.to(device), yb.to(device)

            logits = model(xb)
            loss = criterion(logits, yb)

            val_loss_sum += loss.item() * xb.size(0)
            preds = logits.argmax(1)
            val_correct += (preds == yb).sum().item()
            val_total += xb.size(0)

    val_loss = val_loss_sum / val_total
    val_acc  = val_correct / val_total

    # ---- history + best ----
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    if val_acc > best_acc:
        best_acc = val_acc
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    print(f"Epoch {epoch:02d} | "
          f"train loss {train_loss:.4f} acc {train_acc:.3f} | "
          f"val loss {val_loss:.4f} acc {val_acc:.3f}")

# ---- load & save best ----
if best_state is not None:
    model.load_state_dict({k: v.to(device) for k, v in best_state.items()})
    torch.save(model.state_dict(), "best_intel_classifier.pth")
    print(f"Best val acc: {best_acc:.3f} | Weights saved -> best_intel_classifier.pth")
else:
    print("Warning: best_state is None (перевір, чи є дані у val_dl).")
# Out:
# Epoch 01 | train loss 0.5928 acc 0.797 | val loss 0.3589 acc 0.878
# Epoch 02 | train loss 0.3647 acc 0.869 | val loss 0.3310 acc 0.882
# Epoch 03 | train loss 0.3361 acc 0.881 | val loss 0.3106 acc 0.891
# Epoch 04 | train loss 0.3335 acc 0.880 | val loss 0.2932 acc 0.895
# Epoch 05 | train loss 0.3153 acc 0.886 | val loss 0.2971 acc 0.891
# Epoch 06 | train loss 0.3082 acc 0.885 | val loss 0.2923 acc 0.897
# Epoch 07 | train loss 0.3040 acc 0.887 | val loss 0.3055 acc 0.889
# Epoch 08 | train loss 0.2947 acc 0.892 | val loss 0.3035 acc 0.890
# Epoch 09 | train loss 0.2988 acc 0.890 | val loss 0.3016 acc 0.889
# Epoch 10 | train loss 0.2826 acc 0.895 | val loss 0.3020 acc 0.897
# Epoch 11 | train loss 0.2895 acc 0.891 | val loss 0.2977 acc 0.894
# Epoch 12 | train loss 0.2919 acc 0.893 | val loss 0.3224 acc 0.881
# Epoch 13 | train loss 0.2793 acc 0.895 | val loss 0.2932 acc 0.897
# Epoch 14 | train loss 0.2900 acc 0.893 | val loss 0.2892 acc 0.900
# ...

# %% [markdown]
# ---
#
# ## 📊 Висновок за результатами навчання (25 епох)
#
# * **Динаміка train:**
#   Train loss поступово знижувався з `0.59` до \~`0.27`, а точність піднялася з `0.797` до `0.901`.
#   → Це показує стабільне навчання без явного застою.
#
# * **Динаміка val:**
#   Val loss спочатку знижувався, досягнув мінімуму \~`0.286` на епохах 14–15, а потім трохи коливався у межах `0.28–0.32`.
#   Val accuracy піднявся з `0.878` до **максимуму 0.904** (епоха 21).
#   → Це говорить про гарне узагальнення моделі.
#
# * **Перенавчання:**
#   Невелике коливання валід. loss після 15-ї епохи є нормальним і не свідчить про сильне overfitting (train і val залишаються близькими).
#
# * **Фінальний результат:**
#   Найкраща досягнута **val accuracy = 0.904 (90.4%)**, модель збережена як `best_intel_classifier.pth`.
#   → відповідає очікуваним результатам для transfer learning.
#
# ---
#
# 👉 Коротко: модель добре навчилась, стабільно узагальнює, overfitting мінімальний.
# Можна далі спробувати fine-tuning кількох останніх шарів ResNet або data augmentation, щоб перевищити 92–93% accuracy.

# %% [markdown]
# ## 7 **Оцінка моделі:**
#
# Оцініть продуктивність моделі на тестовому наборі даних.
# Обчисліть метрики, наприклад F1-score тощо. Обґрунтуйте вибір метрики.
#
#
# Опис:
#
# Після тренування й вибору найкращих ваг ми перевіряємо модель на тестовому наборі.
#
# Важливі метрики:
#
# Accuracy — частка правильно класифікованих зображень.
#
# Macro F1-score — збалансована метрика, враховує precision і recall по кожному класу, важлива при дисбалансі.
#
# Confusion Matrix — показує, які класи модель плутає між собою.

# %%
# Test evaluation (uses best weights from step 6)

model.eval()
all_preds, all_targets = [], []

with torch.no_grad():
    for xb, yb in test_dl:
        xb = xb.to(device); yb = yb.to(device)
        logits = model(xb)
        preds = logits.argmax(1)
        all_preds.append(preds.cpu().numpy())
        all_targets.append(yb.cpu().numpy())

y_pred = np.concatenate(all_preds)
y_true = np.concatenate(all_targets)

# %%
# --- Confusion matrix (counts) + metrics without extra imports ---
num_classes = len(full_train.classes)
cm = np.zeros((num_classes, num_classes), dtype=int)
for t, p in zip(y_true, y_pred):
    cm[t, p] += 1

acc = cm.trace() / cm.sum()
print(f"Test Accuracy: {acc:.3f}")
# Out:
# Test Accuracy: 0.896

# %%
# macro-precision/recall/F1 from CM
per_class_f1 = []
for i in range(num_classes):
    tp = cm[i, i]
    fp = cm[:, i].sum() - tp
    fn = cm[i, :].sum() - tp
    prec = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    rec  = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1   = (2 * prec * rec) / (prec + rec) if (prec + rec) > 0 else 0.0
    per_class_f1.append(f1)

macro_f1 = float(np.mean(per_class_f1))

print(f"Test Macro-F1: {macro_f1:.3f}")
# Out:
# Test Macro-F1: 0.897

# %%
# Confusion Matrix (plot, counts)
plt.figure(figsize=(6,6))
im = plt.imshow(cm, cmap="Blues")
plt.title("Confusion Matrix (counts)")
plt.colorbar(im, fraction=0.046, pad=0.04)

ticks = np.arange(num_classes)
plt.xticks(ticks, full_train.classes, rotation=45, ha="right")
plt.yticks(ticks, full_train.classes)

thr = cm.max() * 0.6
for i in range(num_classes):
    for j in range(num_classes):
        plt.text(j, i, cm[i, j],
                 ha="center", va="center",
                 color=("white" if cm[i, j] > thr else "black"), fontsize=9)

plt.xlabel("Predicted"); plt.ylabel("True")
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
#
# ## 📊 Висновок за результатами тесту
#
# * **Загальні метрики**
#
#   * **Test Accuracy = 0.896 (89.6%)**
#   * **Test Macro-F1 = 0.897**
#     → Це підтверджує, що модель узагальнює добре, і її якість стабільна по різних класах (адже F1 близький до accuracy).
#
# * **Матриця помилок (Confusion Matrix)**
#
#   * **Найкраще класифікуються:**
#
#     * *forest* (467/474 правильних),
#     * *sea* (490/510 правильних),
#     * *street* (465/501 правильних).
#       Точність по цих класах дуже висока, помилки поодинокі.
#   * **Слабші результати у:**
#
#     * *mountain*: 416 правильних, але 78 сплутано з *glacier* та ще 24 з *sea*.
#     * *glacier*: 460 правильних, але 50 помилково як *mountain*, ще 34 як *sea*.
#       → Тут є найбільші перехресні помилки.
#   * **buildings:** 389 правильних, але 43 зразки переплутані зі *street*.
#
# * **Причини плутанини:**
#
#   * *glacier* ↔ *mountain* → схожі за текстурою і кольорами (сніг/камінь).
#   * *buildings* ↔ *street* → будівлі часто видні у міських сценах разом із вулицями.
#   * *glacier* ↔ *sea* → можливе через білі відблиски і воду біля льодовиків.
#
# ---
#
# ## ✅ Загальний висновок
#
# Модель досягла **високої точності (89.6%) та збалансованого Macro-F1 (0.897)**. Вона впевнено класифікує більшість класів (*forest, sea, street*), але має труднощі з візуально подібними (*glacier vs mountain*, *buildings vs street*).
# Подальші покращення можуть включати:
#
# * аугментацію з фокусом на варіації кольорів і текстур,
# * fine-tuning кількох шарів ResNet,
# * збільшення роздільної здатності вхідних зображень.
#
# ---

# %% [markdown]
# ## 8 **Аналіз результатів:**
#
# Візуалізуйте результати (наприклад, матрицю помилок, криві навчання).
#
# Проаналізуйте помилки класифікації.

# %% [markdown]
# ✅ Як інтерпретувати
#
# Якщо train loss ↓ і val loss ↓ синхронно → навчання йде добре.
#
# Якщо val loss зростає, а train loss падає → є ризик overfitting.
#
# Якщо обидві криві високі й не падають → underfitting, модель не вчиться.
#
# У нашому випадку (за логом з епохами) val acc стабільно ≈ 0.89–0.90, train acc теж росте → модель добре узагальнює.

# %%
epochs = range(1, len(history["train_loss"]) + 1)

plt.figure(figsize=(12,5))

# --- Loss ---
plt.subplot(1,2,1)
plt.plot(epochs, history["train_loss"], label="Train Loss")
plt.plot(epochs, history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()
plt.grid(True)

# %%
# --- Accuracy ---
plt.subplot(1,2,2)
plt.plot(epochs, history["train_acc"], label="Train Acc")
plt.plot(epochs, history["val_acc"], label="Val Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training & Validation Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # 📊 Аналіз Learning Curves
#
# ### Training & Validation Loss
#
# * **Train loss** швидко знижується на перших епохах (з \~0.59 до \~0.28) і далі стабілізується.
# * **Val loss** також знижується і залишається на рівні \~0.29–0.30 з невеликими коливаннями.
# * Коливання валідаційної кривої — це нормально, і свідчить, що модель реагує на різні батчі, але в середньому утримує стабільний рівень.
#   👉 Ознак значного *overfitting* немає: валідаційні втрати майже збігаються з тренувальними.
#
# ### Training & Validation Accuracy
#
# * **Train accuracy** піднялася з \~0.80 до \~0.90.
# * **Val accuracy** зросла з \~0.88 до \~0.90 і навіть на кількох епохах була вищою за тренувальну.
# * Обидві криві стабільні, без падіння на валідації.
#
# 👉 Це означає, що модель добре узагальнює, не перенавчається і досягла **балансу між train і val**.
#
# ---
#
# ## ✅ Загальний висновок
#
# Модель навчається стабільно, без перенавчання. Валідаційна точність **\~90%** підтверджує, що модель досягла високого рівня узагальнення. Це відповідає очікуванням для **transfer learning (ResNet18)**.
#
# ---

# %%
model.eval()

misclassified = []
with torch.no_grad():
    for imgs, labels in test_dl:
        imgs   = imgs.to(device)     # <-- перенесення на той самий device, що й модель
        labels = labels.to(device)

        logits = model(imgs)
        preds  = torch.argmax(logits, 1)

        # збираємо приклади, де є помилка
        wrong_mask = preds != labels
        if wrong_mask.any():
            for img, y_true, y_pred in zip(imgs[wrong_mask], labels[wrong_mask], preds[wrong_mask]):
                misclassified.append((img.cpu(), int(y_true.cpu()), int(y_pred.cpu())))


# візуалізація перших 9 помилкових випадків
classes = train_ds.dataset.classes

# Малюємо перші 9 помилкових випадків
n = min(9, len(misclassified))
fig, axes = plt.subplots(3, 3, figsize=(8, 8))
for i, ax in enumerate(axes.flat[:n]):
    img, true_label, pred_label = misclassified[i]
    ax.imshow(img.permute(1, 2, 0))
    ax.set_title(f"True: {classes[true_label]}\nPred: {classes[pred_label]}")
    ax.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ## Аналіз помилок класифікації (Misclassified Samples)
#
# На зображеннях вище показані приклади, де модель помилилася.
# Основні спостереження:
#
# - Більшість помилок стосуються класу **buildings**, який часто був передбачений як **street**.
#   Це зрозуміло, оскільки міські будівлі на фото часто включають елементи вулиць (дороги, автомобілі, ліхтарі), що вводить модель в оману.
# - Є випадки, коли **buildings** були віднесені до **mountain** або **glacier** — причина може бути у темному освітленні або наявності великого фону (неба, гір), що нагадує інші категорії.
# - Типові проблеми:
#   - **Недостатня відмінність ознак** між схожими класами (buildings vs street).
#   - **Освітлення та ракурс** суттєво впливають на результат.
#   - Модель поки що більше орієнтується на фон (дорога, гори, небо), ніж на об’єкт.
#
# ### Висновки
# - Найбільший виклик — відокремити **buildings** від **street**.
# - Для покращення результатів можна застосувати:
#   1. **Data augmentation** (зміна яскравості, контрасту, випадкові crop-и), щоб навчити модель бути менш чутливою до освітлення.
#   2. **Балансування класів** (перевірити, чи достатньо прикладів класу *buildings* у наборі даних).
#   3. **Transfer learning з більшою архітектурою** (ResNet50 / EfficientNet), яка краще виокремлює складні ознаки.

# %% [markdown]
# ## 9 **Покращення моделі:**
#
# Спробуйте різні архітектури або гіперпараметри.
#
# Експериментуйте з методами аугментації даних.
#
# При використанні transfer learning, спробуйте «заморозити» деякі шари попередньо навченої моделі.

# %% [markdown]
# ## 9. Покращення моделі
#
# На основі аналізу кривих навчання, матриці помилок та прикладів неправильних класифікацій можна запропонувати наступні шляхи покращення моделі:
#
# 1. **Аугментація даних**
#    - Використання трансформацій (RandomCrop, ColorJitter, RandomRotation, HorizontalFlip).
#    - Це допоможе моделі краще справлятися з різними умовами освітлення та ракурсами.
#    - Очікуваний ефект: зменшення помилок між класами *buildings* і *street*.
#
# 2. **Складніша архітектура (Transfer Learning)**
#    - Перейти з ResNet18 на більш потужну мережу (ResNet50, EfficientNet, DenseNet).
#    - Такі моделі мають багатший набір ознак і краще розрізняють схожі сцени.
#    - Очікуваний ефект: підвищення точності до 92–95%.
#
# 3. **Fine-tuning більше шарів**
#    - Зараз ми перенавчали лише фінальний шар.
#    - Якщо розморозити кілька останніх блоків ResNet і донавчати їх — модель зможе краще підлаштуватися під специфіку набору Intel Image Classification.
#
# 4. **Балансування класів**
#    - Додати ваги класів у функцію втрат (`CrossEntropyLoss(weight=...)`), якщо деякі класи представлені слабше.
#    - Це зменшить перекіс на користь популярніших класів.
#
# 5. **Оптимізація гіперпараметрів**
#    - Зменшення `lr` (наприклад, до 5e-4) або використання планувальника (`StepLR`, `ReduceLROnPlateau`).
#    - Збільшення `epochs` (до 40–50).
#    - Експерименти з batch size (16–64).
#
# ### Висновок
# Модель вже показала хороші результати (accuracy ~90%, F1 ~0.89).
# Однак найбільші проблеми залишаються у відокремленні схожих класів (*buildings* vs *street*, *glacier* vs *mountain*).
# Застосування вищенаведених методів може суттєво покращити якість класифікації та довести модель до рівня state-of-the-art для даного датасету.

# %% [markdown]
# ---
#
# ## Загальний висновок
#
# У цьому домашньому завданні я розробила та навчила модель глибокого навчання для класифікації зображень із набору **Intel Image Classification**, що містить шість категорій природних сцен.
#
# ### Основні результати:
# - Я підготувала дані (train/val/test) із попередньою обробкою (зміна розміру, нормалізація).
# - Для моделювання використала **ResNet18 з transfer learning**, модифікувавши фінальний шар під 6 класів.
# - Навчання тривало 25 епох, із відстеженням train/val loss та accuracy.
# - Найкращі результати на валідації: **accuracy = 0.904**.
# - Під час тестування модель показала:
#   - **Test Accuracy: 0.896**
#   - **Test Macro-F1: 0.897**
#
# ### Аналіз:
# - **Криві навчання** показали стабільне зниження train та val loss без явного overfitting.
# - **Матриця помилок** виявила найбільші труднощі між класами *buildings* ↔ *street* та *glacier* ↔ *mountain*, що пояснюється візуальною схожістю цих сцен.
# - Приклади помилкових класифікацій підтверджують, що модель плутає міські будівлі зі сценами вулиць та гірські регіони з льодовиками.
#
# ### Висновки та покращення:
# - Модель досягла **очікуваних результатів (accuracy ~90%)**, що відповідає прогнозованим діапазонам для transfer learning.
# - Для подальшого покращення можна застосувати:
#   - розширену аугментацію даних (зміни освітлення, повороти, crop);
#   - використання потужніших архітектур (ResNet50, EfficientNet);
#   - fine-tuning декількох останніх блоків ResNet;
#   - оптимізацію гіперпараметрів (lr, batch size, epochs).
#
# ### Загальний підсумок:
# Мені вдалося побудувати **робочу систему класифікації природних сцен**, яка демонструє високу точність та узагальнюючу здатність. Завдання дозволило мені закріпити навички роботи з PyTorch, transfer learning, аналізу кривих навчання та метрик класифікації, а також практично відчути переваги використання попередньо навчених моделей.
